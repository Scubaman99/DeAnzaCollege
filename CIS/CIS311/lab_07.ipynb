# %% [markdown]
# # Lab Assignment 7
#
# Complete the following steps by **filling in your answer in the Code or Text cell below each question**, and then **run the cell** to observe the output.
#
# Before you start working on the lab, please do the following steps:
# - Go to the Settings (gear icon) in the upper right, on the left of the blue "Share" button.
# - Click on the gear icon.
# - At the pop up menu, click on "AI Assistance"
# - Uncheck all 3 boxes, if they're not already unchecked.
# - Click "Close".
#
# This setting will let you do your own work instead of having the AI do all the work.

# %% [markdown]
# For the questions below:
# - If the question has no reference to a class notes Colab notebook, then the question is a review of previous material.
# - If the question refers to Module 7 class notes, then it's new material for Module 7 and the specific section should be helpful as you work on the answer.

# %% [markdown]
# ---

# %% [markdown]
# For this lab we'll work with a dataset of high school student test scores. First we'll do A/B testing with the student scores, then we'll estimate the scores of the general student population within a confidence interval.
#
# First we **import the necessary modules**.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1: Read and Prepare Data
#
# The dataset is from [Kaggle](https://www.kaggle.com/datasets/sh2orc/student-scores-and-hypothesis-testing) and contains high school student data, including the students' math, reading, and writing scores.

# %% [markdown]
# ### Question 1
#
# **Read from the URL into a DataFrame named `students`**.<br>
# Then **print the number of rows and columns of `students`**
# and **print the first 5 rows**.
#
# Make sure to print a text description for the number of rows and columns so it's clear what the numbers are.

# %%
url = "https://raw.githubusercontent.com/DeAnzaDataScience/CIS11/refs/heads/main/datasets_labs/StudentsPerformance.csv"
students =

# %% [markdown]
# ---

# %% [markdown]
# ### Question 2
#
# We're interested in the `math score`, `reading score`, and `writing score` columns. For analysis purpose we would like to use the average of these scores for each student, but we must first check whether it's a good idea to summarize the 3 scores with an average score.
#
# 2a. In the Code cell below, **add code to do the following**:
# - Plot the relationship (or correlation) between the `math score` and `reading score`.
# - Add the appropriate x label and y label.

# %%
plt.figure(figsize=(4,4))
plt.
plt.xlabel(" ")
plt.ylabel(" ")
plt.grid()
plt.show()

# %% [markdown]
# 2b. Similarly, **add code to plot the correlation between the `math score` and `writing score`**.

# %%
plt.figure(figsize=(4,4))
plt.
plt.xlabel(" ")
plt.ylabel(" ")
plt.grid()
plt.show()

# %% [markdown]
# 2c. Lastly, **add code to plot the correlation between the `reading score` and `writing score`**.

# %%
plt.figure(figsize=(4,4))
plt.
plt.xlabel(" ")
plt.ylabel(" ")
plt.grid()
plt.show()

# %% [markdown]
# 2d. It looks like there is strong correlation between the 3 scores. Generally students perform at the same level for all 3 subjects, so we can take the average of the 3 scores to represent the student performance.
#
# **Write code to find the average of the 3 scores for each student** in the `students` DataFrame.<br>
# Then **store the average scores as a new column with the label `score`** in the `students` DataFrame.<br>
# **Print the first 5 rows of `students`**.

# %%
students['score'] =

# %% [markdown]
# ---

# %% [markdown]
# ## Part 2: A/B Testing
#
# We note that there's a `test preparation course` column for each student. Some students didn't take a test preparation course ('none' data value) and some students took the preparation course ('completed' data value).
#
# We would like to see if the test preparation course had an effect on the student score.

# %% [markdown]
# ### Question 3
#
# Based on the Module 7 A/B Testing class notes, "Comparing Two Samples", explain what the A and B are for our student dataset.

# %% [markdown]
# The A group is ...
#
# The B group is ...

# %% [markdown]
# ---

# %% [markdown]
# ### Question 4
#
# We want to compare the test scores between the students who took the test prep course and the students who didn't take the course.
#
# 4a. First we divide the students into 2 groups: `prep` and `no_prep`.
#
# **Write code to do the following**:
# - Create a `prep` group that's made of students whose `test preparation course` is 'completed'.
# - Create a `no_prep` group that's made of students whose `test preparation course` is 'none'.
# - Print the number of students in `prep` and in `no_prep`. Make sure to print text to explain which number is which.

# %%
prep =
no_prep =

# %% [markdown]
# 4b. We visually compare the score distribution of the 2 groups.
#
# Based on the Module 7 A/B Testing class notes, "Comparing Two Samples", **add code to plot the distribution of the scores of `prep` and `no_prep`**.
#
# Make sure to:
# - use `density=True` for the plot.
# - use `alpha=0.4` for the plot so you can see the overlapped distributions.
# - have a legend to explain which distribution belongs to which group.

# %%
plt.figure(figsize=(4, 3))


plt.legend()
plt.title("Score Distribution")
plt.xlabel("Score")
plt.grid()
plt.plot()

# %% [markdown]
# 4c. Based on the Module 7 A/B Testing class notes, "Comparing Two Samples", complete the answer to these 2 questions about the plot:
# - Which group has a higher score?
# - Why do you need to use `density=True`?

# %% [markdown]
# The group with a higher score is ...
#
# We use density=True because ...

# %% [markdown]
# 4d. We also calculate the average score difference between the `prep` and `no_prep` groups of the dataset.
#
# Given the `score_difference` function in the Code cell below, study the function so that you know how to call `score_difference` and give it the required column as input, such that the output is the difference in average score between the `prep` and `no prep` groups.
#
# Add code to **Call the `score_difference` function** and **print the resulting average score difference**.

# %%
def score_difference(column):
    prep = students[students[column] == "completed"]
    no_prep = students[students[column] == "none"]
    return np.mean(prep["score"]) - np.mean(no_prep["score"])

# %% [markdown]
# ---

# %% [markdown]
# ### Question 5
#
# Based on the result of Questions 4c and 4d, it looks like the test preparation course makes a difference in the student scores.
#
# But how do we know that the difference is not due to random chance? Maybe the dataset just happens to contain low scoring students who didn't take the test prep course, and it doesn't contain low scoring students who took the test prep course.

# %% [markdown]
# We'll use A/B testing to answer this question by first defining our hypotheses. Recall that the null hypothesis is always about having no difference between the 2 groups.
#
# In the Text cell below, **write the statements for the null hypothesis and the alternate hypothesis**.

# %% [markdown]
# The null hypothesis:
#
# The alternate hypothesis:

# %% [markdown]
# ---

# %% [markdown]
# ### Question 6
#
# To run our simulation for A/B testing, we need to:
# - Create a sample of shuffled `test preparation course`.
# - Find the difference in average scores between the two groups for the sample.
# - Repeat the above 2 steps many times to get a distribution of average score differences.

# %% [markdown]
# 6a. Based on the Module 7 A/B Testing class notes, "Comparing Two Samples" section, **write a function named `one_sample` which does the following**:
# - Shuffle the `test preparation course` data, and stores the shuffled data in a column of the `students`DataFrame, name the column `shuffled`.
# - Call the `score_difference` function in step 4d, passing the `shuffled` column as input.
# - Return the average score difference.
#
# Then **call the `one_sample` function**  and **print the output** of the function.

# %%
def one_sample

# %% [markdown]
# 6b. Now we repeat the sampling 10,000 times to obtain the distribution of average score differences.
#
# **Write code to do the following steps**:
# - Create a list L to store the average score differences
# - Loop 10,000 times, and in the loop:
# > - Call `one_sample` to get the score difference for the sample.
# > - Store the score differences in L.
# - When the loop is done, convert L to a numpy array named `differences`.
# - Print the number of data values in `differences`.

# %%
L = []

# %% [markdown]
# ---

# %% [markdown]
# ### Question 7
#
# We now analyze the simulated differences to see if it rejects or fails to reject the null hypothesis.
#
# 7a. Add code to the Code cell below to **plot the distribution of the `differences`**.

# %%
plt.figure(figsize=(5, 3))

plt.xlabel("Score Difference")
plt.grid()
plt.plot()

# %% [markdown]
# 7b. In step 4d we found the observed average score difference between the `prep` and `no_prep` group for the given dataset.
#
# Comparing:
# - the observed average score difference of step 4d, and
# - the simulated average score difference distribution above
#
# In the Text cell below, **enter your answer for the following 2 questions**:<br>
# a. Do the results reject or fail to reject the null hypothesis? Why?<br>
# b. What does your answer for part (a) tell you about the effect of the test preparation course?
#
# Once again, the Module 7 A/B Testing class notes, "Comparing Two Samples" section can be helpful.

# %% [markdown]
# a. The results ...
#
# b. The answer of part a shows ...

# %% [markdown]
# 7c. Based on the Module 7 A/B Testing class notes, "Comparing Two Samples" section, as further proof of your answer of part 7b, add code to the Code cell below to **calculate and print the p-value of the observed average score difference**.
#
# Then in the Text cell, **discuss how it agrees with your conclusion** above.

# %%
p_value =

# %% [markdown]
# The p-value ...

# %% [markdown]
# ---

# %% [markdown]
# ## Part 3: Estimation
#
# Using the student scores in the dataset, we'd like to estimate a statistic of the scores of the general population of students.
#
# **Run the Code cell below** to review the `students` DataFrame

# %%
print("First 5 rows:")
students.head()

# %% [markdown]
# ### Question 8
#
# To estimate the average reading score of the student population from the `reading score` in the dataset, we use the bootstrap process.
#
# 8a. Based on the Module 7 Estimation class notes, "Bootstrap" section, **write a `resample` function** that does the following:
# - Sample the entire `students` DataFrame _with replacement_.
# - Return the mean of the `reading score` of the new sample.
#
# Then **call the `resample` function** and **print the average reading score**.

# %% [markdown]
# 8b. In the Text cell below, **enter your answer** for this question:<br>
# For resampling, why is it important to sample with replacement?

# %% [markdown]
# Sample with replacement ...

# %% [markdown]
# 8c. We run the `resample` function many times to get the distribution of average reading scores from the samples.
#
# **Write code to do the following steps**:
# - Create a list L to store all the average reading scores.
# - Loop 10,000 times to call the `resample` function and store the output in L.
# - When the loop is done, convert the list L to a numpy array named `average_array`.
# - Print the number of data values in `average_array`.

# %%
L =

# %% [markdown]
# 8d. Based on the Module 7 Estimation class notes, "Percentile" and "Confidence Interval" sections,  **write code to print the range of average reading scores of the student population, with a 95% confidence interval**.
#
# The average scores should be stated as a range: from score1 to score2<br>
# And the scores should be rounded to 3 digits after the decimal point.

# %%
# 95% confidence interval

# %% [markdown]
# 8e. Similarly, **write code to print the range of average reading scores of the student population, with an 80% confidence interval**.

# %%
# 80% confidence interval

# %% [markdown]
# 8f. In the Text cell below, **enter your answer for the following question**:<br>
# Why is the score range of the 80% confidence interval smaller than the score range of the 95% confidence interval?

# %% [markdown]
# The 95% confidence interval means ...
#
# The 80% confidence interval means ...
