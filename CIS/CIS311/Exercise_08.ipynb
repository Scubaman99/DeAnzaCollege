# %% [markdown]
# # Module 8 Practice Exercise
#
# Goal: properties of the mean, standard deviation, standard units, central limit theorem

# %% [markdown]
# This exercise works with the dataset for Bike Sharing in the Bay Area, which was also used in Module 4 exercise.<br>
# The data is collected by a bike sharing program where people can pick up a bike to use for a short time and then return the bike.
#
# 1. Run the following Code cell to read in the file.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

url = 'https://raw.githubusercontent.com/DeAnzaDataScience/CIS11/main/datasets_exercises/trip.csv'
trips = pd.read_csv(url)
trips

# %% [markdown]
# For this exercise we'll work with the `Duration` column, or the length of time people rent the bike. And we only work with the duration of 1800 seconds or less, which we found from Exercise 4, was 95% of the dataset.
#
# 2a. Write code to copy the rows where `Duration` is 1800 sec or less, then copy and save the `Duration` data with the variable name `duration`.<br>
# Then print the number of data values in `duration`.

# %%
duration = 
print("Number of data values:", len(duration))

# %% [markdown]
# 2b. Add code to find the mean and save it with the name `average`, and find the median and save it with the name `mid`.

# %%
average = 
mid = 
print("Average duration:", average)
print("Median duration:", mid)

# %% [markdown]
# 2b. Explain what might be the reason why the mean (average) is higher than the median?

# %% [markdown]
# The mean is higher because ...

# %% [markdown]
# 3. Add code below to plot the histogram for the `duration` and plot the mean and median.

# %%
plt.figure(figsize=(4,4))


plt.scatter(average, 0, color='red', s=40, zorder=2)
plt.scatter(mid, 0, color='yellow', s=40, zorder=2)
plt.xlabel('Trip Duration in seconds')
plt.title('Trip Duration Histogram')
plt.grid()   
plt.show()

# %% [markdown]
# 4. Add code to find and print the standard deviation named `sd`.<br>
# Then fill in the code to plot the histogram of `duration` and the 2 SD lines as 2 dashed red lines.

# %%
sd = 
print("Standard deviation:", sd)

plt.figure(figsize=(4,4))


plt.scatter(average, 0, color='red', s=40, zorder=2)
plt.axvline(  )
plt.axvline(  )
plt.xlabel('Trip Duration in seconds')
plt.title('Trip Duration Histogram')
plt.grid()   
plt.show()

# %% [markdown]
# 5. The data that are in between the two red dashed lines are, at minimum, what percentage of all the data?

# %% [markdown]
# The data between the 2 red dashed lines is at least ...

# %% [markdown]
# 6a. Given the `standard_units` function that converts original units of data to standard units.<br>
# Run the Code cell to let Python know about the function.

# %%
def standard_units(array):
    return (array - np.mean(array))/np.std(array)

# %% [markdown]
# 6b. Add code to convert the `duration` to standard units, named `duration_su`, and plot the histogram of `duration_su`.

# %%
duration_su = 

plt.figure(figsize=(4,4))
plt.hist(duration_su, edgecolor='black')
plt.xlabel('Trip Duration in standard units')
plt.title('Trip Duration Histogram')
plt.grid()   
plt.show()

# %% [markdown]
# 7a. Is the shape of the histogram in standard units the same as the shape of the histogram in original units?<br>
# 7b. For the histogram in standard units, the location of the mean is at what value along the x-axis?

# %% [markdown]
# 7a answer:
#
# 7b answer:

# %% [markdown]
# ---

# %% [markdown]
# 8. Now we work with the central limit theorem, which states that if we plot the mean of large samples of the `duration`, we expect the distribution to be what type of curve?

# %% [markdown]
# Expect the curve to be ...

# %% [markdown]
# 9. We run simulation to prove that the central limit theorem is true.
#
# Fill in the code to create function that takes a sample of 500 durations. Should it be a sample with or without replacement?

# %%
def get_sample_mean():
    return np.mean(  )

# %% [markdown]
# 10. Fill in the code to loop 10,000, and in the loop:
# - Create a sample of 500 values
# - Add to a list L the mean of the samples

# %%
L = []
for i in range(10000):
    
    
sample_mean =

# %% [markdown]
# 11. Plot the histogram of the `sample_mean`.

# %%
plt.figure(figsize=(4,4))
plt.hist(sample_mean, edgecolor='black')
plt.xlabel('Mean of Samples')
plt.title('Distribution of Sample Means')
plt.grid()   
plt.show()
