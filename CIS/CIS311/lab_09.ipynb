# %% [markdown]
# # Lab Assignment 9
#
# Complete the following steps by **filling in your answer in the Code or Text cell below each question**, and then **run the cell** to observe the output.
#
# Before you start working on the lab, please do the following steps:
# - Go to the Settings (gear icon) in the upper right, on the left of the blue "Share" button.
# - Click on the gear icon.
# - At the pop up menu, click on "AI Assistance"
# - Uncheck all 3 boxes, if they're not already unchecked.
# - Click "Close".
#
# This setting will let you do your own work instead of having the AI do all the work.

# %% [markdown]
# For the questions below:
# - If the question has no reference to a class notes Colab notebook, then the question is a review of previous material.
# - If the question refers to Module 9 class notes, then it's new material for Module 9 and the specific section should be helpful as you work on the answer.

# %% [markdown]
# ---

# %% [markdown]
# For this lab we will work with the student test scores that we've used in Lab 7. We'll see if we can predict a student's writing score if we know the student's reading score. Then we'll use the same technique to see if we can predict the student's math score.
#
# First we **import the necessary modules**.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1: Read Data

# %% [markdown]
# ### Question 1
#
# Similar to Lab 7, **read from the URL into a DataFrame named `students`**.<br>
# Then **print the number of rows and columns of `students`**
# and **print the first 5 rows**.
#
# Make sure to print a text description for the number of rows and columns so it's clear what the numbers are.

# %%
url = "https://raw.githubusercontent.com/DeAnzaDataScience/CIS11/refs/heads/main/datasets_labs/StudentsPerformance.csv"
students =

# %% [markdown]
# The `math score`, `reading score`, and `writing score` are the columns that we'll work use for this lab.

# %% [markdown]
# ---

# %% [markdown]
# ## Part 2: Reading and Writing Prediction
#
# Usually students' reading scores and writing scores are related. Someone who has good reading comprehension will tend to have good writing skills also.
#
# We'll use the students' reading scores and see how well we can predict their writing scores.

# %% [markdown]
# ### Question 2
#
# In order to predict with some accuracy, we need to first check whether there's correlation between the two data sequences.
#
# 2a. In the Code cell below, **add code to visually show the correlation between `reading score` and `writing score`**.

# %%
plt.figure(figsize=(4, 4))


plt.xlabel("Reading Score")
plt.ylabel("Writing Score")
plt.grid()
plt.show()

# %% [markdown]
# 2b. In the Text cell below, **enter your answers for these 2 questions**:
#
# - Does it look like a strong correlation? Why?
# - Is it a positive or negative correlation? Why?

# %% [markdown]
# There is a ... correlation because ...
#
# It's a ... correlation because ...

# %% [markdown]
# 2c. In addition to visually check the correlation betwen `reading score` and `writing score`, we also want to find the actual correlation coefficient. Do the following 3 steps:
#
# - Based on Module 9 class notes, "The Correlation Coefficient" section, **copy the function to find the `correlation`** into the Code cell below.
#
# - The `correlation` function calls the `standard units` function in the Module 9 class notes, "Standard Units" section, so it's important to also **copy the `standard units` function** into the Code cell.
#
# - There's a specific order that you need to place these 2 functions in the Code cell, and it's in the order that the functions need to run. Make sure the 2 functions are shown in the correct order.
#
# - Write code to use the 2 functions to **find the correlation `r` between the two scores**. Then **run the Code cell**, giving it the `reading score` and `writing score` as input, and **print the correlation coefficient**.

# %%
print("r:",  )

# %% [markdown]
# 2d. Does the correlation coefficient agree with the scatterplot?
#
# In the Text cell below, **explain your answer**.

# %% [markdown]
# The correlation coefficient is ...

# %% [markdown]
# ---

# %% [markdown]
# ### Question 3
#
# We now find the formula for the regression line, because then we can use the formula with the computer so that it can predict many values for us.
#
# We recall from Module 9 class notes, "Calculate the Regression Line" section, that the formula to describe a line in the (x,y) plane is:<br>
# `y = slope * x + intercept`

# %% [markdown]
# 3a. Based on Module 9 class notes, "Calculate the Regression Line" section, **copy the function to find the `slope`, using actual units of x and y** into the Code cell below. Make sure it's the function that uses _actual units_ of x and y, and not _standard units_ of x and y.
#
# Then **run the Code cell** to let Python know about the `slope` function.

# %%
def slope

# %% [markdown]
# 3b. Based on Module 9 class notes, "Calculate the Regression Line" section, **copy the function to find the `intercept`, using actual units of x and y** into the Code cell below. Make sure it's the function that uses _actual units_ of x and y, and not _standard units_ of x and y.
#
# Then **run the Code cell** to let Python know about the `intercept` function.

# %%
def intercept

# %% [markdown]
# 3c. We now calculate the slope of the regression line.
#
# Based on Module 9 class notes, "Calculate the Regression Line" section, write code to **create an `rw_slope` array** (rw for reading-writing) with the students' reading and writing scores.
#
# Then **run the Code cell** to create the array.

# %%
rw_slope =

# %% [markdown]
# 3d. Similarly, we calculate the intercept of the regression line.
#
# Based on Module 9 class notes, "Calculate the Regression Line" section, write code to **create an `rw_intercept` array** with the students' reading and writing scores.
#
# Then **run the Code cell** to create the array.

# %%
rw_intercept =

# %% [markdown]
# 3e. We plot the regression line in the scatterplot to visually inspect it.
#
# **Add code to do the following steps**:
# - Plot the scatterplot of the students' reading and writing scores. Use `alpha=0.4` so it's easier to see the regression line.
# - Plot the regression line with `color="darkgreen"` so it's easier to see the regression line.

# %%
plt.figure(figsize=(4, 4))


plt.xlabel("Reading Score")
plt.ylabel("Writing Score")
plt.grid()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Question 4
#
# We do a visual inspection of the regression line, which is our prediction line.
#
# 4a. Observing the plot above, do you think that the predicted writing scores would generally be fairly accurate?
#
# In the Text cell below, **enter <u>your reasoning</u> for whether the regression line is a fairly accurate prediction of writing scores**.

# %% [markdown]
# The regression line is ...

# %% [markdown]
# 4b. Observing the plot above, do you see a range of reading scores where the predicted writing scores would most likely be not so accurate? Why do you think it might not be accurate?
#
# In the Text cell below, **enter <u>your explanation</u> for which range of reading scores might produce inaccurate predictions of writing scores**.

# %% [markdown]
# Reading scores in the range ...

# %% [markdown]
# ---

# %% [markdown]
# ## Part 3: Writing and Math Prediction
#
# The reading and math scores can potentially not be as closely correlated as the reading and writing scores. Some people are naturally better at math than writing, and other people are the reverse.
#
# In this Part 3 we repeat some of the steps in Part 2 to see if we can predict students' math scores from writing scores.

# %% [markdown]
# ### Question 5
#
# 5a. Before using linear regression, we always first check the correlation of the 2 data sequences.
#
# **Add code to plot the correlation between `writing scores` and `math scores`**.

# %%
plt.figure(figsize=(4, 4))


plt.xlabel("Writing Score")
plt.ylabel("Math Score")
plt.grid()
plt.show()

# %% [markdown]
# 5b. In the Code cell below, **add all the code needed to create the same scatterplot but add its regresssion line in the plot**, with these **3** requirements:
#
# - The Code cell should produce the same kind of plot as Question 3e.
# - The Code cell should only have the necessary code to produce the scatterplot. This means you should not have to copy every Code cell of Part 2.
# - For every Code cell that you copy and modify for Part 3, add a line of Python comment to explain what the copied code does.

# %%
plt.grid()
plt.show()

# %% [markdown]
# 5c. Observing the plot from Question 5b, do you expect the accuracy of the predicted math scores to be lower or higher than the accuracy of the predicted writing scores in Part 2? Why?
#
# In the Text cell below, **enter <u>your explanation</u>** for whether the accuracy for predicted math scores is likely higher or lower than the predicted scores of Part 2.

# %% [markdown]
# The accuracy of the predicted writing scores is ...
