# %% [markdown]
# # Module 11 Exercise
#
# Goal: create a classifier

# %% [markdown]
# We continue with the iris dataset ([source](https://archive.ics.uci.edu/dataset/53/iris)) from Module 10 exercise, which is a classic dataset used in statistics and machine learning. It contains data of 3 types of iris flowers.
#
# Instead of just looking at the `petal_length` and `petal_width`, we will create a classifier that works with all 4 relevant features of the iris.
#
# 1. Run the following Code cell to read in data, print the numbers of rows and columns, and display the first 5 rows.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/DeAnzaDataScience/CIS11/refs/heads/main/datasets_exercises/iris.csv"
iris = pd.read_csv(url)
rows, columns = iris.shape
print("Number of rows:", rows)
print("Number of columns:", columns)
print("First 5 rows:")
iris.head()

# %% [markdown]
# 2. Recall from the class notes that using all <i>relevant</i> features can help the classifier be more accurate.<br>
# In the Text cell below, show the advantages of using all relevant features, then show the disadvantages of using all relevant features.

# %% [markdown]
# Advantage:
#
# Disadvantage:

# %% [markdown]
# 3. The relevant features for the iris dataset are all 4 columns: sepal length and width, and petal length and width.
#
# Since we work with a binary classifier, we will use only 2 of the 3 species.<br>
# 3a. Write code to find the count of species so we can see the 3 species and their count.

# %%
iris.

# %% [markdown]
# 3b. We'll choose the first 2 species.<br>
# Write code to create a new DataFrame with only `Iris-setosa` and `Iris-versicolor` species. Name this new DataFrame `iris2` for two species only.

# %%
iris2 = 
iris2.head()

# %% [markdown]
# 3c. Check that there are only 2 species by running the same code as step 3a with `iris2`

# %%
iris2.

# %% [markdown]
# 4. Now we're ready to create the classifier.
#
# - First we need a function that can find the distance between 2 points, then we need a function that finds the distances between the new data point and all the other data points. Find these 2 functions in the class notes and bring them in the Code cell below.
# - For the function that find all the distances between the new point and all other data points, change the column name that should be dropped, - - Run the Code cell to let Python know about the 2 functions.

# %%
# find distance between new point and one of the training data point


# find distances between new point and all the training data points
# What column name should be dropped?

# %% [markdown]
# 4. Copy the function to find the k nearest neighbors from the class notes to the Code cell below, then run the cell to let Python know about the function.

# %%
# find k nearest neighbors

# %% [markdown]
# 5. From the class notes, find the 2 functions to calculate the group of the majority of the k nearest neighbors.
# - Copy to the Code cell below.
# - Change the fuction that checks for the majority: it should count data based on `species` and return the appropriate `species`.
# - Then run the cell to let Python know about the function.

# %%
def 

def classify

# %% [markdown]
# Now that we have the classifier code, we need to create the training and testing dataset.
#
# 6. Write code to huffle the `iris2` data and create a training and testing dataset.

# %%
shuffled_data = 
training_set = 
testing_set =

# %% [markdown]
# 7. Save the `species` column of the testing set to an array named `actual`, then drop the `species` column from the testing set.

# %%
actual = 
testing_set =

# %% [markdown]
# 8. Use the classifier and 3 neearest neighbors to predict the species of the testing set, save the predictions in an array named `predicted`

# %%
predicted =

# %% [markdown]
# 9. Write code to find the accuracy of the classifier.

# %%
print("Accuracy:", )
