# %% [markdown]
# # Module 10 Exercise
#
# Goal: RMSE, Classification

# %% [markdown]
# In the first part of the exercise we explore RMSE, which is a way to measure how accurate the linear regression predictions are.<br>
# We work with a dataset of fathers' heights and their sons' heights, which came from the Dept of Statistics at UC Berkeley.
#
# 1. Run the Code cell below to read in the data and print the number of rows and columns, and the first 5 rows.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/mdogy/dataForEng1999/master/sons_heights.csv"
height = pd.read_csv(url)
rows, columns = height.shape
print("Number of rows:", rows)
print("Number of columns:", columns)
print("First 5 rows:")
height.head()

# %% [markdown]
# 2. We take a look at the correlation between fathers' heights and sons' heights to see if there's an association between them.<br>
# Fill in the Code cell below to diplay the plot to show correlation.

# %%
plt.figure(figsize=(4,4))


plt.xlabel("Fathers' Heights")
plt.ylabel("Sons' Heights")
plt.grid()
plt.show()

# %% [markdown]
# 3. It seems that as the fathers' heights increase, generally the sons' height also increase.
#
# 3a. Find the correlation coefficient `r`

# %%
r = 
print("r:", r)

# %% [markdown]
# 3b. Find the slope `s` and intercept `i` of the linear regression line.

# %%
s = 



i = 

print("slope:", s)
print("intercept:", i)

# %% [markdown]
# 3c. Fill in the code below to show the linear regression line in `green` on the scatterplot of step 2.

# %%
plt.figure(figsize=(4,4))


plt.xlabel("Fathers' Heights")
plt.ylabel("Sons' Heights")
plt.grid()
plt.show()

# %% [markdown]
# 4. Find the predicted sons' height by using the linear regression line.<br>
# Then store the predicted values in a new column of `height` named `predicted`.

# %%
predicted_sons_heights = 
height['predicted'] = 
height.head()

# %% [markdown]
# 5. Find the difference between the actual `son`'s heights and the `predicted` sons' heights.<br>
# Store the result in a new column of `height` named `error`.

# %%
differences = 
height['error'] =
height.head()

# %% [markdown]
# 6a. Find the RMSE and the relative RMSE percentage.

# %%
rmse = 
print("RMSE:", rmse)

print("Relative RMSE percent:", )

# %% [markdown]
# 6b. Is this a good relative RMSE percentage?

# %% [markdown]
# The relative RMSE percentage is ...

# %% [markdown]
# ---

# %% [markdown]
# In Part 2 of the exercise we will work with another type of prediction called classification.<br>
# We use the iris dataset ([source](https://archive.ics.uci.edu/dataset/53/iris)), which is a classic dataset used in statistics and machine learning. It contains data of 3 types of iris flowers.
#
# 7. Run the following Code cell to read in data, print the numbers of rows and columns, and display the first 5 rows.

# %%
url = "https://raw.githubusercontent.com/DeAnzaDataScience/CIS11/refs/heads/main/datasets_exercises/iris.csv"
iris = pd.read_csv(url)
rows, columns = iris.shape
print("Number of rows:", rows)
print("Number of columns:", columns)
print("First 5 rows:")
iris.head()

# %% [markdown]
# 8. We will look at the petals of the flowers, specifically the `petal_length` and `petal_width`.
#
# 8a. Fill in the code below to display the scatterplot of `petal_length` and `petal_width`.

# %%
plt.figure(figsize=(4,4))


plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.grid()
plt.show()

# %% [markdown]
# 8b. Run the following Code cell to change the data to standard units. Then display the scatterplot again.

# %%
def standard_units(array):
    return (array - np.mean(array))/np.std(array)



plt.figure(figsize=(4,4))


plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.grid()
plt.show()

# %% [markdown]
# 9. There seems to be some association between the petal lengths and widths. The larger the length, the larger the width.<br>
# However, we would like to see if the lengths and widths are different between the 3 species.
#
# Fill in the code below to separate the data into 3 groups, and plot the petal lengths vs widths for each group.

# %%
plt.figure(figsize=(4,4))

groups = 

for name, group in groups:
    

plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 10. Now it's more clear how to determine the type of iris if we know the length and width of the petal. The 'setosa' has the smallest sized petal, the 'versicolor' has a medium size petal, and the 'virginica' has the largest petal.
#
# Given that a new iris has a petal length of -1 standard units and petal width of -0.25 standard units, which type of iris would you predict it to be?

# %% [markdown]
# The iris is of type ...

# %% [markdown]
# 11. Run the following 2 Code cells to find the data points closest to the new iris data point of (-1, -0.25).

# %%
# find the nearest blue 'setosa'
data1 = iris[(iris['petal_width'] < -0.5) & (iris['petal_width'] > -1)]
data1

# %% [markdown]
# Out of the nearest 2 'setosa', the one at index 43 is closest to the new iris of (-1, -0.25)

# %%
# find the nearest orange 'versicolor'
data2 = iris[(iris['petal_length'] < -0.2) & (iris['petal_length'] > -1)]
data2

# %% [markdown]
# Out of the nearest 3 'versicolor', the ones at index 98 and index 93 (or 57) are the closest to the new iris of (-1, -0.25)

# %% [markdown]
# 12a. Change the function below, which is from the Module 10 Classification notes, so that it works for iris data.<br>
# Then run the Code cell to let Python know about the function.
# ```
# def find_distance_to_Alice(row):
#     run = alice_age - row['Age']
#     rise = alice_salary - row['EstimatedSalary']
#     return np.sqrt(run**2 + rise**2)
# ```

# %%
def find_distance_to_new_iris(row):
    run = 
    rise = 
    return np.sqrt(run**2 + rise**2)

# %% [markdown]
# 12b. Use `find_distance_to_new_iris` to find the distance from the new iris to the row at index 43, 93, and 98.

# %%
print("Distance to row at index 43:",  )
print("Distance to row at index 93:",  )
print("Distance to row at index 98:",  )

# %% [markdown]
# 12c. Which is the nearest neighbor to the new iris?

# %% [markdown]
# The nearest neightbor is ...
