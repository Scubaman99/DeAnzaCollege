# %% [markdown]
# # Module 9 Practice Exercise
#
# Goal: linear regression

# %% [markdown]
# This exercise uses the dataset from [Kaggle](https://www.kaggle.com/datasets/raniritu/electricity-bill-prediction/data), which contains data for a certain units of electricity used and the corresponding electric bill. We want to predict the electric bill, given the units of electricity used.
#
# 1. Run the following Code cell to read in the data, print the number of rows and columns of data, and show the first 5 rows.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/DeAnzaDataScience/CIS11/refs/heads/main/datasets_exercises/electricity.csv"
electricity = pd.read_csv("electricity.csv")
rows,columns = electricity.shape
print("Number of rows:", rows)
print("Number of columns:", columns)
print("First 5 rows:")
electricity.head()

# %% [markdown]
# 2. To determine if linear regression can be used to predict the bill, we need to check whether the association between the bill and the units of electricity used is linear.
#
# Add to the code below to print a scatterplot of `Units_Consumed` and `Electricity_Bill`.

# %%
plt.figure(figsize=(4,4))


plt.xlabel('Units of Electricty')
plt.ylabel('Bill')
plt.grid(True)
plt.show()

# %% [markdown]
# It looks like the association between the units of electricity used and the electric bill is a linear relationship.
#
# 3. Find the correlation coefficient `r`.
#
# 3a. Given the above scatterplot, do you expect `r` to be positive or negative?<br>
# Do you expect `r` to be closer to 1 or closer to 0?

# %% [markdown]
# r is expected to be ...
#
# r is expected to be closer to ...

# %% [markdown]
# 3b. Find `r` by filling in the code below.<br>

# %%
r = 
print("r:", r)

# %% [markdown]
# 4. Find the slope `s` of the regression line.

# %%
s = 
print("slope:", s)

# %% [markdown]
# 5. Find the intercept `i` of the regression line.

# %%
    
i = 
print("intercept:", i)

# %% [markdown]
# 6. Fill in the code to show the regression line in 'red' with the scatterplot of step 2.

# %%
plt.figure(figsize=(4,4))


plt.xlabel('Units of Electricty')
plt.ylabel('Bill')
plt.grid(True)
plt.show()

# %% [markdown]
# 7. What is the expected bill for 350 units of electricity used?<br>
# Write code to find and print the answer.

# %%
bill =
print("The expected bill is", round(bill,2))
